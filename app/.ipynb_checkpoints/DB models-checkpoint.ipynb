# %%
from sqlalchemy import create_engine, MetaData, Table
from sqlalchemy.engine import reflection
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

# %%
import config

# %%
conn_str="postgresql+psycopg2://" + config.DEV_DB_USER + ":" + config.DEV_DB_PASS + "@localhost:5432/" + config.DEV_DB_NAME

# %%
conn_str
# Out:
# 'postgresql+psycopg2://postgres:tpt@14jml@localhost:5432/campnearme'

# %%
engine = create_engine(conn_str)
Base = declarative_base(engine)

# %%
meta = MetaData()

# %%
class RidbFacilities(Base):
    __tablename__ = 'ridb_facilities_orig'
    __table_args__ = {'autoload':True}
    
class RidbCampsites(Base):
    __tablename__ = 'ridb_campgrounds_orig'
    __table_args__ = {'autoload':True}
    
def loadSession():
        metadata = Base.metadata
        Session = sessionmaker(bind=engine)
        session = Session()
        return session
    
if __name__ == "__main__":
        session = loadSession()
        res = session.query(RidbFacilities).all()
        print(res)
# Out:
# [<__main__.RidbFacilities object at 0x10309e320>, <__main__.RidbFacilities object at 0x10309e390>, <__main__.RidbFacilities object at 0x10309e400>, <__main__.RidbFacilities object at 0x10309e470>, <__main__.RidbFacilities object at 0x10309e4e0>, <__main__.RidbFacilities object at 0x10309e550>, <__main__.RidbFacilities object at 0x10309e5c0>, <__main__.RidbFacilities object at 0x10309e630>, <__main__.RidbFacilities object at 0x10309e6a0>, <__main__.RidbFacilities object at 0x10309e710>, <__main__.RidbFacilities object at 0x10309e780>, <__main__.RidbFacilities object at 0x10309e7f0>, <__main__.RidbFacilities object at 0x10309e860>, <__main__.RidbFacilities object at 0x10309e8d0>, <__main__.RidbFacilities object at 0x10309e940>, <__main__.RidbFacilities object at 0x10309e9b0>, <__main__.RidbFacilities object at 0x10309ea20>, <__main__.RidbFacilities object at 0x10309ea90>, <__main__.RidbFacilities object at 0x10309eb00>, <__main__.RidbFacilities object at 0x10309eb70>, <__main__.RidbFacilities object at 0x10309ec18>, <__main__.RidbFacilities object at 0x10309ecc0>, <__main__.RidbFacilities object at 0x10309ed68>, <__main__.RidbFacilities object at 0x10309ee10>, <__main__.RidbFacilities object at 0x10309eeb8>, <__main__.RidbFacilities object at 0x10309ef60>, <__main__.RidbFacilities object at 0x1030b8048>, <__main__.RidbFacilities object at 0x1030b80f0>, <__main__.RidbFacilities object at 0x1030b8198>, <__main__.RidbFacilities object at 0x1030b8240>, <__main__.RidbFacilities object at 0x1030b82e8>, <__main__.RidbFacilities object at 0x1030b8390>, <__main__.RidbFacilities object at 0x1030b8438>, <__main__.RidbFacilities object at 0x1030b84e0>, <__main__.RidbFacilities object at 0x1030b8588>, <__main__.RidbFacilities object at 0x1030b8630>, <__main__.RidbFacilities object at 0x1030b86d8>, <__main__.RidbFacilities object at 0x1030b8780>, <__main__.RidbFacilities object at 0x1030b8828>, <__main__.RidbFacilities object at 0x1030b88d0>, <__main__.RidbFacilities object at 0x1030b8978>, <__main__.RidbFacilities object at 0x1030b8a20>, <__main__.RidbFacilities object at 0x1030b8ac8>, <__main__.RidbFacilities object at 0x1030b8b70>, <__main__.RidbFacilities object at 0x1030b8c18>, <__main__.RidbFacilities object at 0x1030b8cc0>, <__main__.RidbFacilities object at 0x1030b8d68>, <__main__.RidbFacilities object at 0x1030b8e10>, <__main__.RidbFacilities object at 0x1030b8eb8>, <__main__.RidbFacilities object at 0x1030b8f60>, <__main__.RidbFacilities object at 0x1030be048>, <__main__.RidbFacilities object at 0x1030be0f0>, <__main__.RidbFacilities object at 0x1030be198>, <__main__.RidbFacilities object at 0x1030be240>, <__main__.RidbFacilities object at 0x1030be2e8>, <__main__.RidbFacilities object at 0x1030be390>, <__main__.RidbFacilities object at 0x1030be438>, <__main__.RidbFacilities object at 0x1030be4e0>, <__main__.RidbFacilities object at 0x1030be588>, <__main__.RidbFacilities object at 0x1030be630>, <__main__.RidbFacilities object at 0x1030be6d8>, <__main__.RidbFacilities object at 0x1030be780>, <__main__.RidbFacilities object at 0x1030be828>, <__main__.RidbFacilities object at 0x1030be8d0>, <__main__.RidbFacilities object at 0x1030be978>, <__main__.RidbFacilities object at 0x1030bea20>, <__main__.RidbFacilities object at 0x1030beac8>, <__main__.RidbFacilities object at 0x1030beb70>, <__main__.RidbFacilities object at 0x1030bec18>, <__main__.RidbFacilities object at 0x1030becc0>, <__main__.RidbFacilities object at 0x1030bed68>, <__main__.RidbFacilities object at 0x1030bee10>, <__main__.RidbFacilities object at 0x1030beeb8>, <__main__.RidbFacilities object at 0x1030bef60>, <__main__.RidbFacilities object at 0x1030c2048>, <__main__.RidbFacilities object at 0x1030c20f0>, <__main__.RidbFacilities object at 0x1030c2198>, <__main__.RidbFacilities object at 0x1030c2240>, <__main__.RidbFacilities object at 0x1030c22e8>, <__main__.RidbFacilities object at 0x1030c2390>, <__main__.RidbFacilities object at 0x1030c2438>, <__main__.RidbFacilities objec ...
# /usr/local/lib/python3.5/site-packages/sqlalchemy/ext/declarative/clsregistry.py:120: SAWarning: This declarative base already contains a class with the same class name and module name as __main__.RidbFacilities, and will be replaced in the string-lookup table.
#   item.__name__
# /usr/local/lib/python3.5/site-packages/sqlalchemy/ext/declarative/clsregistry.py:120: SAWarning: This declarative base already contains a class with the same class name and module name as __main__.RidbCampsites, and will be replaced in the string-lookup table.
#   item.__name__

# %%
Table('facilitydetails', meta, autoload=True, autoload_with=engine)

# %%
[c.name for c in  facility_details.columns]

# %%
facility_full_details = Table('facility_full_details', meta, autoload=True, autoload_with=engine )

# %%
[c.name for c in  facility_full_details.columns]

# %%
[t.name for t in meta.sorted_tables]

# %%
facility_details.schema
